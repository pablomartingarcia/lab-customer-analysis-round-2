# %% [markdown]
# 1. Show the dataframe shape.

# %%
import pandas as pd

df = pd.read_csv("/Users/suso/BootcampDA/Unit1/Labs/lab-customer-analysis-round-2/files_for_lab/csv_files/marketing_customer_analysis.csv")

print(df.shape)
# Out:
# (10910, 26)

# %% [markdown]
# 2. Standardize header names.

# %%
df.head()
df.columns = df.columns.str.upper().str.replace(" ", "_")

# %%
df.head()
# Out:
#    UNNAMED:_0 CUSTOMER       STATE  CUSTOMER_LIFETIME_VALUE RESPONSE  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    COVERAGE EDUCATION EFFECTIVE_TO_DATE EMPLOYMENTSTATUS GENDER  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    NUMBER_OF_OPEN_COMPLAINTS NUMBER_OF_POLICIES     POLICY_TYPE        POLICY  \
# ...

# %% [markdown]
# 3. Which columns are numerical?
# 4. Which columns are categorical?

# %%
df.dtypes
# Out:
# UNNAMED:_0                         int64
# CUSTOMER                          object
# STATE                             object
# CUSTOMER_LIFETIME_VALUE          float64
# RESPONSE                          object
# COVERAGE                          object
# EDUCATION                         object
# EFFECTIVE_TO_DATE                 object
# EMPLOYMENTSTATUS                  object
# GENDER                            object
# INCOME                             int64
# LOCATION_CODE                     object
# MARITAL_STATUS                    object
# MONTHLY_PREMIUM_AUTO               int64
# MONTHS_SINCE_LAST_CLAIM          float64
# MONTHS_SINCE_POLICY_INCEPTION      int64
# NUMBER_OF_OPEN_COMPLAINTS        float64
# NUMBER_OF_POLICIES                 int64
# POLICY_TYPE                       object
# POLICY                            object
# RENEW_OFFER_TYPE                  object
# SALES_CHANNEL                     object
# TOTAL_CLAIM_AMOUNT               float64
# ...

# %% [markdown]
# 5. Check and deal with NaN values.

# %%
data1 = df.copy()

# %%
data1.isnull()
# Out:
#        UNNAMED:_0  CUSTOMER  STATE  CUSTOMER_LIFETIME_VALUE  RESPONSE  \
# 0           False     False  False                    False     False
# 1           False     False  False                    False     False
# 2           False     False  False                    False     False
# 3           False     False  False                    False     False
# 4           False     False  False                    False     False
# ...           ...       ...    ...                      ...       ...
# 10905       False     False  False                    False     False
# 10906       False     False  False                    False     False
# 10907       False     False  False                    False     False
# 10908       False     False  False                    False     False
# 10909       False     False   True                    False      True
#
#        COVERAGE  EDUCATION  EFFECTIVE_TO_DATE  EMPLOYMENTSTATUS  GENDER  ...  \
# ...

# %%
data1.isnull().sum()
# Out:
# UNNAMED:_0                          0
# CUSTOMER                            0
# STATE                             631
# CUSTOMER_LIFETIME_VALUE             0
# RESPONSE                          631
# COVERAGE                            0
# EDUCATION                           0
# EFFECTIVE_TO_DATE                   0
# EMPLOYMENTSTATUS                    0
# GENDER                              0
# INCOME                              0
# LOCATION_CODE                       0
# MARITAL_STATUS                      0
# MONTHLY_PREMIUM_AUTO                0
# MONTHS_SINCE_LAST_CLAIM           633
# MONTHS_SINCE_POLICY_INCEPTION       0
# NUMBER_OF_OPEN_COMPLAINTS         633
# NUMBER_OF_POLICIES                  0
# POLICY_TYPE                         0
# POLICY                              0
# RENEW_OFFER_TYPE                    0
# SALES_CHANNEL                       0
# TOTAL_CLAIM_AMOUNT                  0
# VEHICLE_CLASS                     622
# VEHICLE_SIZE                      622
# ...

# %%
data1['STATE'] = data1['STATE'].fillna('California')

# %%
data1.isnull().sum()
# Out:
# UNNAMED:_0                          0
# CUSTOMER                            0
# STATE                               0
# CUSTOMER_LIFETIME_VALUE             0
# RESPONSE                          631
# COVERAGE                            0
# EDUCATION                           0
# EFFECTIVE_TO_DATE                   0
# EMPLOYMENTSTATUS                    0
# GENDER                              0
# INCOME                              0
# LOCATION_CODE                       0
# MARITAL_STATUS                      0
# MONTHLY_PREMIUM_AUTO                0
# MONTHS_SINCE_LAST_CLAIM           633
# MONTHS_SINCE_POLICY_INCEPTION       0
# NUMBER_OF_OPEN_COMPLAINTS         633
# NUMBER_OF_POLICIES                  0
# POLICY_TYPE                         0
# POLICY                              0
# RENEW_OFFER_TYPE                    0
# SALES_CHANNEL                       0
# TOTAL_CLAIM_AMOUNT                  0
# VEHICLE_CLASS                     622
# VEHICLE_SIZE                      622
# ...

# %%
value_counts = df['STATE'].value_counts()
print(value_counts)
# Out:
# STATE
# California    3552
# Oregon        2909
# Arizona       1937
# Nevada         993
# Washington     888
# Name: count, dtype: int64

# %%
value_counts = df['RESPONSE'].value_counts()
print(value_counts)
# Out:
# RESPONSE
# No     8813
# Yes    1466
# Name: count, dtype: int64

# %%
data1['RESPONSE'] = data1['RESPONSE'].fillna('No')

# %%
value_counts = df['MONTHS_SINCE_LAST_CLAIM'].value_counts()
print(value_counts)
# Out:
# MONTHS_SINCE_LAST_CLAIM
# 3.0     426
# 6.0     394
# 1.0     386
# 7.0     378
# 4.0     373
# 2.0     368
# 5.0     355
# 0.0     354
# 10.0    346
# 16.0    333
# 11.0    331
# 15.0    323
# 13.0    320
# 8.0     315
# 12.0    307
# 17.0    299
# 14.0    299
# 9.0     277
# 23.0    276
# 19.0    276
# 25.0    269
# 21.0    267
# 18.0    257
# 20.0    254
# 22.0    246
# 24.0    237
# 29.0    234
# 28.0    227
# 31.0    221
# 26.0    211
# 27.0    208
# 30.0    201
# 34.0    199
# 33.0    198
# 35.0    157
# 32.0    155
# Name: count, dtype: int64

# %%
data1['MONTHS_SINCE_LAST_CLAIM'] = data1['MONTHS_SINCE_LAST_CLAIM'].fillna(data1['MONTHS_SINCE_LAST_CLAIM'].mean())

# %%
data1['NUMBER_OF_OPEN_COMPLAINTS'] = data1['NUMBER_OF_OPEN_COMPLAINTS'].fillna(data1['NUMBER_OF_OPEN_COMPLAINTS'].mean())

# %%
value_counts = df['VEHICLE_CLASS'].value_counts()
print(value_counts)
# Out:
# VEHICLE_CLASS
# Four-Door Car    5212
# Two-Door Car     2118
# SUV              2012
# Sports Car        550
# Luxury SUV        208
# Luxury Car        188
# Name: count, dtype: int64

# %%
data1['VEHICLE_CLASS'] = data1['VEHICLE_CLASS'].fillna('Four-Door Car')

# %%
value_counts = df['VEHICLE_SIZE'].value_counts()
print(value_counts)
# Out:
# VEHICLE_SIZE
# Medsize    7251
# Small      1966
# Large      1071
# Name: count, dtype: int64

# %%
data1['VEHICLE_SIZE'] = data1['VEHICLE_SIZE'].fillna('Medsize')

# %%
value_counts = df['VEHICLE_TYPE'].value_counts()
print(value_counts)
# Out:
# VEHICLE_TYPE
# A    5428
# Name: count, dtype: int64

# %%
data1['VEHICLE_TYPE'] = data1['VEHICLE_TYPE'].fillna('A')

# %%
data1.isnull().sum()
# Out:
# UNNAMED:_0                       0
# CUSTOMER                         0
# STATE                            0
# CUSTOMER_LIFETIME_VALUE          0
# RESPONSE                         0
# COVERAGE                         0
# EDUCATION                        0
# EFFECTIVE_TO_DATE                0
# EMPLOYMENTSTATUS                 0
# GENDER                           0
# INCOME                           0
# LOCATION_CODE                    0
# MARITAL_STATUS                   0
# MONTHLY_PREMIUM_AUTO             0
# MONTHS_SINCE_LAST_CLAIM          0
# MONTHS_SINCE_POLICY_INCEPTION    0
# NUMBER_OF_OPEN_COMPLAINTS        0
# NUMBER_OF_POLICIES               0
# POLICY_TYPE                      0
# POLICY                           0
# RENEW_OFFER_TYPE                 0
# SALES_CHANNEL                    0
# TOTAL_CLAIM_AMOUNT               0
# VEHICLE_CLASS                    0
# VEHICLE_SIZE                     0
# VEHICLE_TYPE                     0
# dtype: int64

# %% [markdown]
# 6. Datetime format - Extract the months from the dataset and store in a separate column. Then filter the data to show only the information for the first quarter , ie. January, February and March. Hint: If data from March does not exist, consider only January and February.

# %%
data1['EFFECTIVE_TO_DATE'] = pd.to_datetime(data1['EFFECTIVE_TO_DATE']) # , errors='coerce'
data1['EFFECTIVE_TO_DATE']
# Out:
# 0       2011-02-18
# 1       2011-01-18
# 2       2011-02-10
# 3       2011-01-11
# 4       2011-01-17
#            ...
# 10905   2011-01-19
# 10906   2011-01-06
# 10907   2011-02-06
# 10908   2011-02-13
# 10909   2011-01-08
# Name: EFFECTIVE_TO_DATE, Length: 10910, dtype: datetime64[ns]

# %%
data1['EFFECTIVE_TO_DATE'][0]#.day # .month   #.year   #.isoweekday() # .time()
# Out:
# Timestamp('2011-02-18 00:00:00')

# %%
data1['Month'] = data1['EFFECTIVE_TO_DATE'].dt.month

# %%
first_quarter = data1[data1['Month'].isin([1, 2, 3])]

# %%
first_quarter.head()
# Out:
#    UNNAMED:_0 CUSTOMER       STATE  CUSTOMER_LIFETIME_VALUE RESPONSE  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    COVERAGE EDUCATION EFFECTIVE_TO_DATE EMPLOYMENTSTATUS GENDER  ...  \
# 0     Basic   College        2011-02-18         Employed      M  ...
# 1     Basic   College        2011-01-18       Unemployed      F  ...
# 2     Basic  Bachelor        2011-02-10         Employed      M  ...
# 3  Extended   College        2011-01-11         Employed      M  ...
# 4   Premium  Bachelor        2011-01-17    Medical Leave      F  ...
#
#    NUMBER_OF_POLICIES     POLICY_TYPE        POLICY  RENEW_OFFER_TYPE  \
# ...
